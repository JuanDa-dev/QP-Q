# %%
! pip install numpy matplotlib qiskit 
! pip install qiskit-aer

# %%
import qiskit
from qiskit import QuantumCircuit, QuantumRegister
from qiskit import transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
from qiskit.quantum_info import Statevector
import numpy as np

# Definir el ket inicial
initial_state = [np.sqrt(3)/2, 1/2]  # (sqrt(3)/2)|0> + (1/2)|1>
np.array([[np.sqrt(3)/2],
          [1/2]])
# Out:
# array([[0.8660254],
#        [0.5      ]])

# %%
# Crear un circuito cuántico con 1 qubit e inicializar el estado
qc = QuantumCircuit(1)
qc.initialize(initial_state, 0)

# %%
# Ubicar el ket inicial en la esfera de Bloch
state = Statevector(qc)
print(state)
plot_bloch_multivector(state)
# Out:
# Statevector([0.8660254+0.j, 0.5      +0.j],
#             dims=(2,))

# %%
# Aplicar la compuerta X y ubicar el nuevo ket en la esfera de Bloch
qc.x(0)
state = Statevector(qc)
print(state)
plot_bloch_multivector(state)
# Out:
# Statevector([0.5      +0.j, 0.8660254+0.j],
#             dims=(2,))

# %%
# Aplicar la compuerta Y y ubicar el nuevo ket en la esfera de Bloch
qc.y(0)
state = Statevector(qc)
print(state)
plot_bloch_multivector(state)
# Out:
# Statevector([0.-0.8660254j, 0.+0.5j      ],
#             dims=(2,))

# %%
# Aplicar la compuerta Z y ubicar el nuevo ket en la esfera de Bloch
qc.z(0)
state = Statevector(qc)
print(state)
plot_bloch_multivector(state)
# Out:
# Statevector([ 0.5      +0.j, -0.8660254+0.j],
#             dims=(2,))

# %%
# Aplicar la compuerta H y ubicar el nuevo ket en la esfera de Bloch
qc.h(0)
state = Statevector(qc)
print(state)
plot_bloch_multivector(state)
# Out:
# Statevector([-0.25881905+0.j,  0.96592583+0.j],
#             dims=(2,))
